# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown, display, HTML
from collections import defaultdict
from sklearn.model_selection import KFold
import time

# Fix the dying kernel problem (only a problem in some installations - you can remove it, if it works without it)
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load the data

# %%
ml_ratings_df = pd.read_csv(os.path.join("data", "movielens_small", "ratings.csv")).rename(columns={'userId': 'user_id', 'movieId': 'item_id'})
ml_movies_df = pd.read_csv(os.path.join("data", "movielens_small", "movies.csv")).rename(columns={'movieId': 'item_id'})
ml_df = pd.merge(ml_ratings_df, ml_movies_df, on='item_id')
ml_df.head(10)

display(HTML(ml_movies_df.head(10).to_html()))

# Filter the data to reduce the number of movies
seed = 6789
rng = np.random.RandomState(seed=seed)
left_ids = rng.choice(ml_movies_df['item_id'], size=1000, replace=False)

ml_ratings_df = ml_ratings_df.loc[ml_ratings_df['item_id'].isin(left_ids)]
ml_movies_df = ml_movies_df.loc[ml_movies_df['item_id'].isin(left_ids)]
ml_df = ml_df.loc[ml_df['item_id'].isin(left_ids)]

print("Number of left interactions: {}".format(len(ml_ratings_df)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item_id</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Toy Story (1995)</td>
#       <td>Adventure|Animation|Children|Comedy|Fantasy</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Jumanji (1995)</td>
#       <td>Adventure|Children|Fantasy</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Grumpier Old Men (1995)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Waiting to Exhale (1995)</td>
#       <td>Comedy|Drama|Romance</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Father of the Bride Part II (1995)</td>
#       <td>Comedy</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Heat (1995)</td>
#       <td>Action|Crime|Thriller</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Sabrina (1995)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Tom and Huck (1995)</td>
#       <td>Adventure|Children</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Sudden Death (1995)</td>
#       <td>Action</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>GoldenEye (1995)</td>
#       <td>Action|Adventure|Thriller</td>
#     </tr>
#   </tbody>
# </table>
# Number of left interactions: 9692

# %% [markdown]
# # Recommender class
#
# Remark: Docstrings written in reStructuredText (reST) used by Sphinx to automatically generate code documentation. It is also used by default by PyCharm (type triple quotes after defining a class or a method and hit enter).

# %%
class Recommender(object):
    """
    Base recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        
        :param int seed: Seed for the random number generator.
        """
        pass
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        pass
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': [-1] * n_recommendations,
                                                 'score': [3.0] * n_recommendations})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

# %% [markdown]
# # Evaluation measures

# %% [markdown]
# ## Explicit feedback - ratings

# %% [markdown]
# ### MAE - Mean Absolute error
#
# <center>
# $$
#     MAE = \frac{\sum_{i}^N |\hat{r}_i - r_i|}{N}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Easily interpretable.
#     - Non-differentiable which makes it unsuitable for gradient descent.
#     - The scale of errors dependent on data which reduced comparability between different datasets.

# %%
def mae(r_pred, r_real):
    return np.sum(np.abs(r_pred - r_real)) / len(r_pred)

# Test

# Very small differences
print("MAE = {:.3f}".format(mae(np.array([2.99, 1.98, 3.99, 4.97, 1.01]), np.array([3, 2, 4, 5, 1]))))
# Small differences
print("MAE = {:.3f}".format(mae(np.array([2.8, 1.7, 3.8, 4.6, 1.6]), np.array([3, 2, 4, 5, 1]))))
# Large differences
print("MAE = {:.3f}".format(mae(np.array([1.1, 4.2, 2.8, 3.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Medium differences with one large difference
print("MAE = {:.3f}".format(mae(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Small differences with one very large difference
print("MAE = {:.3f}".format(mae(np.array([2.8, 1.7, 3.8, 4.6, 4.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# MAE = 0.016
# MAE = 0.340
# MAE = 1.940
# MAE = 1.060
# MAE = 0.940

# %% [markdown]
# ### RMSE - Root Mean Squared Error
#
# <center>
# $$
#     RMSE = \sqrt{\frac{\sum_{i}^N (\hat{r}_i - r_i)^2}{N}}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Very well-behaved analytically and therefore extensively used to train models, especially neural networks.
#     - The scale of errors dependent on data which reduced comparability between different datasets.

# %%
def rmse(r_pred, r_real):
    return np.sqrt(np.sum(np.power(r_pred - r_real, 2)) / len(r_pred))

# Test

# Very small differences
print("RMSE = {:.3f}".format(rmse(np.array([2.99, 1.98, 3.99, 4.97, 1.01]), np.array([3, 2, 4, 5, 1]))))
# Small differences
print("RMSE = {:.3f}".format(rmse(np.array([2.8, 1.7, 3.8, 4.6, 1.6]), np.array([3, 2, 4, 5, 1]))))
# Large differences
print("RMSE = {:.3f}".format(rmse(np.array([1.1, 4.2, 2.8, 3.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Medium differences with one large difference
print("RMSE = {:.3f}".format(rmse(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Small differences with one very large difference
print("RMSE = {:.3f}".format(rmse(np.array([2.8, 1.7, 3.8, 4.6, 4.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# RMSE = 0.018
# RMSE = 0.371
# RMSE = 1.994
# RMSE = 1.333
# RMSE = 1.630

# %% [markdown]
# ### MRE - Mean Relative Error (more often called MAPE)
#
# <center>
# $$
#     MRE = \frac{1}{N} \sum_{i}^N \frac{|\hat{r}_i - r_i|}{|r_i|}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Easily interpretable (average percentage error) and with a meaning understandable for business.
#     - Blows up when there are values close to zero among the predicted values.

# %%
def mre(r_pred, r_real):
    return 1 / len(r_pred) * np.sum(np.abs(r_pred - r_real) / np.abs(r_real))

# Test

# Very small differences
print("MRE = {:.3f}".format(mre(np.array([2.99, 1.98, 3.99, 4.97, 1.01]), np.array([3, 2, 4, 5, 1]))))
# Small differences
print("MRE = {:.3f}".format(mre(np.array([2.8, 1.7, 3.8, 4.6, 1.6]), np.array([3, 2, 4, 5, 1]))))
# Large differences
print("MRE = {:.3f}".format(mre(np.array([1.1, 4.2, 2.8, 3.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Medium differences with one large difference
print("MRE = {:.3f}".format(mre(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Small differences with one very large difference for a small base value
print("MRE = {:.3f}".format(mre(np.array([2.8, 1.7, 3.8, 4.6, 4.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# MRE = 0.006
# MRE = 0.189
# MRE = 0.999
# MRE = 0.702
# MRE = 0.789

# %% [markdown]
# ### TRE - Total Relative Error
#
# <center>
# $$
#     TRE = \frac{\sum_{i}^N |\hat{r}_i - r_i|}{\sum_{i}^N |r_i|}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Easily interpretable (total percentage error) and with a meaning understandable for business.
#     + Reliable even for very small predicted values.
#     - Does not distinguish between a case when one prediction is very bad and other are very good and a case when all predictions are mediocre.

# %%
def tre(r_pred, r_real):
    return np.sum(np.abs(r_pred - r_real)) / np.sum(np.abs(r_real))

# Test

# Very small differences
print("TRE = {:.3f}".format(tre(np.array([2.99, 1.98, 3.99, 4.97, 1.01]), np.array([3, 2, 4, 5, 1]))))
# Small differences
print("TRE = {:.3f}".format(tre(np.array([2.8, 1.7, 3.8, 4.6, 1.6]), np.array([3, 2, 4, 5, 1]))))
# Large differences
print("TRE = {:.3f}".format(tre(np.array([1.1, 4.2, 2.8, 3.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Medium differences with one large difference
print("TRE = {:.3f}".format(tre(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Small differences with one very large difference for a small base value
print("TRE = {:.3f}".format(tre(np.array([2.8, 1.7, 3.8, 4.6, 4.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# TRE = 0.005
# TRE = 0.113
# TRE = 0.647
# TRE = 0.353
# TRE = 0.313

# %% [markdown]
# ## Implicit feedback - binary indicators of interactions

# %% [markdown]
# ### HR@n - Hit Ratio
# How many hits did we score in the first n recommendations.
# <br/>
# <br/>
# <center>
# $$
#     \text{HR@}n = \frac{\sum_{u} \sum_{i \in I_u} r_{u, i} \cdot 1_{\hat{D}_n(u)}(i)}{M}
# $$
# </center>
#
# where:
#   * $r_{u, i}$ is $1$ if there was an interaction between user $u$ and item $i$ in the test set and $0$ otherwise,
#   * $\hat{D}_n$ is the set of the first $n$ recommendations for user $u$,
#   * $1_{\hat{D}_n}(i)$ is $1$ if and only if $i \in \hat{D}_n$, otherwise it's equal to $0$,
#   * $M$ is the number of users.
#
#
#     + Easily interpretable.
#     - Does not take the rank of each recommendation into account.

# %%
def hr(recommendations, real_interactions, n=1):
    """
    Assumes recommendations are ordered by user_id and then by score.
    """
    # Transform real_interactions to a dict for a large speed-up
    rui = defaultdict(lambda: 0)
    
    for idx, row in real_interactions.iterrows():
        rui[(row['user_id'], row['item_id'])] = 1
        
    hr = 0.0
    
    previous_user_id = -1
    rank = 0
    for idx, row in recommendations.iterrows():
        if previous_user_id == row['user_id']:
            rank += 1
        else:
            rank = 1
            
        if rank <= n:
            hr += rui[(row['user_id'], row['item_id'])]
        
        previous_user_id = row['user_id']
    
    hr /= len(recommendations['user_id'].unique())
    
    return hr

# %%
# Case 1
    
real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(real_interactions)
    
recommendations = pd.DataFrame(
    [
        [1, 45, 0.9],
        [1, 13, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(recommendations)
    
print("HR@3 = {:.4f}".format(hr(recommendations, real_interactions, n=3)))
# Out:
#    user_id  item_id
# 0        1       45
# 1        1       22
# 2        1       77
# 3        2       13
# 4        2       77
#    user_id  item_id  score
# 0        1       45   0.90
# 1        1       13   0.80
# 2        1       22   0.71
# 3        1       77   0.55
# 4        1        9   0.52
# 5        2       11   0.85
# 6        2       13   0.69
# 7        2       25   0.64
# 8        2        6   0.60
# 9        2       77   0.53
# HR@3 = 1.5000

# %%
# Case 2
    
real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(real_interactions)
    
recommendations = pd.DataFrame(
    [
        [1, 13, 0.9],
        [1, 45, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(recommendations)
    
print("HR@3 = {:.4f}".format(hr(recommendations, real_interactions, n=3)))
# Out:
#    user_id  item_id
# 0        1       45
# 1        1       22
# 2        1       77
# 3        2       13
# 4        2       77
#    user_id  item_id  score
# 0        1       13   0.90
# 1        1       45   0.80
# 2        1       22   0.71
# 3        1       77   0.55
# 4        1        9   0.52
# 5        2       11   0.85
# 6        2       13   0.69
# 7        2       25   0.64
# 8        2        6   0.60
# 9        2       77   0.53
# HR@3 = 1.5000

# %% [markdown]
# ### NDCG@n - Normalized Discounted Cumulative Gain
#
# How many hits did we score in the first n recommendations discounted by the position of each recommendation.
# <br/>
# <br/>
# <center>
# $$
#     \text{NDCG@}n = \frac{\sum_{u} \sum_{i \in I_u} \frac{r_{u, i}}{log\left(1 + v_{\hat{D}_n(u)}(i)\right)}}{M}
# $$
# </center>
#
# where:
#   * $r_{u, i}$ is $1$ if there was an interaction between user $u$ and item $i$ in the test set and $0$ otherwise,
#   * $\hat{D}_n(u)$ is the set of the first $n$ recommendations for user $u$,
#   * $v_{\hat{D}_n(u)}(i)$ is the position of item $i$ in recommendations $\hat{D}_n$,
#   * $M$ is the number of users.
#
#
#     - Takes the rank of each recommendation into account.

# %%
def ndcg(recommendations, real_interactions, n=1):
    """
    Assumes recommendations are ordered by user_id and then by score.
    """
    # Transform real_interactions to a dict for a large speed-up
    rui = defaultdict(lambda: 0)
    
    for idx, row in real_interactions.iterrows():
        rui[(row['user_id'], row['item_id'])] = 1
        
    ndcg = 0.0
    
    previous_user_id = -1
    rank = 0
    for idx, row in recommendations.iterrows():
        if previous_user_id == row['user_id']:
            rank += 1
        else:
            rank = 1
            
        if rank <= n:
            ndcg += rui[(row['user_id'], row['item_id'])] / np.log2(1 + rank)
        
        previous_user_id = row['user_id']
    
    ndcg /= len(recommendations['user_id'].unique())
    
    return ndcg

# %%
# Case 1
    
real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(real_interactions)
    
recommendations = pd.DataFrame(
    [
        [1, 45, 0.9],
        [1, 13, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(recommendations)
    
print("NDCG@3 = {:.4f}".format(ndcg(recommendations, real_interactions, n=3)))
# Out:
#    user_id  item_id
# 0        1       45
# 1        1       22
# 2        1       77
# 3        2       13
# 4        2       77
#    user_id  item_id  score
# 0        1       45   0.90
# 1        1       13   0.80
# 2        1       22   0.71
# 3        1       77   0.55
# 4        1        9   0.52
# 5        2       11   0.85
# 6        2       13   0.69
# 7        2       25   0.64
# 8        2        6   0.60
# 9        2       77   0.53
# NDCG@3 = 1.0655

# %%
# Case 2
    
real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(real_interactions)
    
recommendations = pd.DataFrame(
    [
        [1, 13, 0.9],
        [1, 45, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(recommendations)
    
print("NDCG@3 = {:.4f}".format(ndcg(recommendations, real_interactions, n=3)))
# Out:
#    user_id  item_id
# 0        1       45
# 1        1       22
# 2        1       77
# 3        2       13
# 4        2       77
#    user_id  item_id  score
# 0        1       13   0.90
# 1        1       45   0.80
# 2        1       22   0.71
# 3        1       77   0.55
# 4        1        9   0.52
# 5        2       11   0.85
# 6        2       13   0.69
# 7        2       25   0.64
# 8        2        6   0.60
# 9        2       77   0.53
# NDCG@3 = 0.8809

# %% [markdown]
# # Testing routines (offline)

# %% [markdown]
# ## Train and test set split

# %% [markdown]
# ### Explicit feedback

# %%
def evaluate_train_test_split_explicit(recommender, interactions_df, items_df, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    if type(interactions_df) == dict:
        # If interactions_df is a dict with already split data, use the split
        interactions_df_train = interactions_df['train']
        interactions_df_test = interactions_df['test']
    else:    
        # Otherwise split the dataset into train and test

        shuffle = np.arange(len(interactions_df))
        rng.shuffle(shuffle)
        shuffle = list(shuffle)

        train_test_split = 0.8
        split_index = int(len(interactions_df) * train_test_split)

        interactions_df_train = interactions_df.iloc[shuffle[:split_index]]
        interactions_df_test = interactions_df.iloc[shuffle[split_index:]]
    
    # Train the recommender
    
    recommender.fit(interactions_df_train, None, items_df)
    
    # Gather predictions
    
    r_pred = []
    
    for idx, row in interactions_df_test.iterrows():
        users_df = pd.DataFrame([row['user_id']], columns=['user_id'])
        eval_items_df = pd.DataFrame([row['item_id']], columns=['item_id'])
        eval_items_df = pd.merge(eval_items_df, items_df, on='item_id')
        recommendations = recommender.recommend(users_df, eval_items_df, n_recommendations=1)
        print(recommendations)
        r_pred.append(recommendations.iloc[0]['score'])
    
    # Gather real ratings
    
    r_real = np.array(interactions_df_test['rating'].tolist())
    
    # Return evaluation metrics
    
    return rmse(r_pred, r_real), mre(r_pred, r_real), tre(r_pred, r_real)

recommender = Recommender()

results = [['BaseRecommender'] + list(evaluate_train_test_split_explicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])

display(HTML(results.to_html()))
# Out:
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0    247.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    469.0      -1    3.0
#    user_id item_id  score
# 0     70.0      -1    3.0
#    user_id item_id  score
# 0    246.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0     61.0      -1    3.0
#    user_id item_id  score
# 0    217.0      -1    3.0
#    user_id item_id  score
# 0    495.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    141.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    218.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    451.0      -1    3.0
#    user_id item_id  score
# 0    169.0      -1    3.0
#    user_id item_id  score
# 0    475.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    256.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    219.0      -1    3.0
#    user_id item_id  score
# 0     51.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0     73.0      -1    3.0
#    user_id item_id  score
# 0     74.0      -1    3.0
#    user_id item_id  score
# 0    561.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    241.0      -1    3.0
#    user_id item_id  score
# 0    270.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    239.0      -1    3.0
#    user_id item_id  score
# 0    186.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    276.0      -1    3.0
#    user_id item_id  score
# 0     57.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    607.0      -1    3.0
#    user_id item_id  score
# 0    312.0      -1    3.0
#    user_id item_id  score
# 0    376.0      -1    3.0
#    user_id item_id  score
# 0    224.0      -1    3.0
#    user_id item_id  score
# 0    428.0      -1    3.0
#    user_id item_id  score
# 0     44.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0      5.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    271.0      -1    3.0
#    user_id item_id  score
# 0    479.0      -1    3.0
#    user_id item_id  score
# 0    353.0      -1    3.0
#    user_id item_id  score
# 0    137.0      -1    3.0
#    user_id item_id  score
# 0     77.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    221.0      -1    3.0
#    user_id item_id  score
# 0     51.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0     42.0      -1    3.0
#    user_id item_id  score
# 0    152.0      -1    3.0
#    user_id item_id  score
# 0    282.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    103.0      -1    3.0
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    580.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     15.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    571.0      -1    3.0
#    user_id item_id  score
# 0    239.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    574.0      -1    3.0
#    user_id item_id  score
# 0    601.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0    273.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    289.0      -1    3.0
#    user_id item_id  score
# 0    217.0      -1    3.0
#    user_id item_id  score
# 0    435.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0    135.0      -1    3.0
#    user_id item_id  score
# 0    410.0      -1    3.0
#    user_id item_id  score
# 0    137.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0     50.0      -1    3.0
#    user_id item_id  score
# 0    162.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0     73.0      -1    3.0
#    user_id item_id  score
# 0    260.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    204.0      -1    3.0
#    user_id item_id  score
# 0    352.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0     38.0      -1    3.0
#    user_id item_id  score
# 0    260.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0     59.0      -1    3.0
#    user_id item_id  score
# 0    199.0      -1    3.0
#    user_id item_id  score
# 0     79.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    602.0      -1    3.0
#    user_id item_id  score
# 0    262.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    331.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    427.0      -1    3.0
#    user_id item_id  score
# 0    593.0      -1    3.0
#    user_id item_id  score
# 0    113.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0     22.0      -1    3.0
#    user_id item_id  score
# 0    469.0      -1    3.0
#    user_id item_id  score
# 0    266.0      -1    3.0
#    user_id item_id  score
# 0    287.0      -1    3.0
#    user_id item_id  score
# 0    313.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0     20.0      -1    3.0
#    user_id item_id  score
# 0    199.0      -1    3.0
#    user_id item_id  score
# 0    563.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    524.0      -1    3.0
#    user_id item_id  score
# 0    379.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    495.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    600.0      -1    3.0
#    user_id item_id  score
# 0    462.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    517.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    169.0      -1    3.0
#    user_id item_id  score
# 0    437.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    402.0      -1    3.0
#    user_id item_id  score
# 0    562.0      -1    3.0
#    user_id item_id  score
# 0    323.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0     51.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    204.0      -1    3.0
#    user_id item_id  score
# 0    227.0      -1    3.0
#    user_id item_id  score
# 0    328.0      -1    3.0
#    user_id item_id  score
# 0     31.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    348.0      -1    3.0
#    user_id item_id  score
# 0    465.0      -1    3.0
#    user_id item_id  score
# 0    561.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0     51.0      -1    3.0
#    user_id item_id  score
# 0    279.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0     64.0      -1    3.0
#    user_id item_id  score
# 0    480.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    129.0      -1    3.0
#    user_id item_id  score
# 0    484.0      -1    3.0
#    user_id item_id  score
# 0    480.0      -1    3.0
#    user_id item_id  score
# 0    359.0      -1    3.0
#    user_id item_id  score
# 0    540.0      -1    3.0
#    user_id item_id  score
# 0    181.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    463.0      -1    3.0
#    user_id item_id  score
# 0    183.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    217.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    561.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0     61.0      -1    3.0
#    user_id item_id  score
# 0     25.0      -1    3.0
#    user_id item_id  score
# 0    457.0      -1    3.0
#    user_id item_id  score
# 0     22.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0     17.0      -1    3.0
#    user_id item_id  score
# 0     21.0      -1    3.0
#    user_id item_id  score
# 0    160.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    139.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0    419.0      -1    3.0
#    user_id item_id  score
# 0    262.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    286.0      -1    3.0
#    user_id item_id  score
# 0     29.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    200.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    301.0      -1    3.0
#    user_id item_id  score
# 0    607.0      -1    3.0
#    user_id item_id  score
# 0    109.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    268.0      -1    3.0
#    user_id item_id  score
# 0    186.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    546.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    469.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    354.0      -1    3.0
#    user_id item_id  score
# 0    462.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    198.0      -1    3.0
#    user_id item_id  score
# 0    202.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    566.0      -1    3.0
#    user_id item_id  score
# 0    605.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    187.0      -1    3.0
#    user_id item_id  score
# 0    588.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0     38.0      -1    3.0
#    user_id item_id  score
# 0    352.0      -1    3.0
#    user_id item_id  score
# 0    301.0      -1    3.0
#    user_id item_id  score
# 0    195.0      -1    3.0
#    user_id item_id  score
# 0     60.0      -1    3.0
#    user_id item_id  score
# 0    317.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    475.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0    561.0      -1    3.0
#    user_id item_id  score
# 0     36.0      -1    3.0
#    user_id item_id  score
# 0    417.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    221.0      -1    3.0
#    user_id item_id  score
# 0    423.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    462.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    280.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     98.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0    501.0      -1    3.0
#    user_id item_id  score
# 0    202.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    142.0      -1    3.0
#    user_id item_id  score
# 0    331.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    365.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    385.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    111.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0     33.0      -1    3.0
#    user_id item_id  score
# 0    113.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    328.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0    101.0      -1    3.0
#    user_id item_id  score
# 0    284.0      -1    3.0
#    user_id item_id  score
# 0    230.0      -1    3.0
#    user_id item_id  score
# 0    554.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    334.0      -1    3.0
#    user_id item_id  score
# 0     61.0      -1    3.0
#    user_id item_id  score
# 0    446.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    465.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    233.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0     46.0      -1    3.0
#    user_id item_id  score
# 0    503.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    559.0      -1    3.0
#    user_id item_id  score
# 0    118.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    323.0      -1    3.0
#    user_id item_id  score
# 0    267.0      -1    3.0
#    user_id item_id  score
# 0    200.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    260.0      -1    3.0
#    user_id item_id  score
# 0    405.0      -1    3.0
#    user_id item_id  score
# 0    543.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0    559.0      -1    3.0
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    239.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    296.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    405.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    234.0      -1    3.0
#    user_id item_id  score
# 0    464.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    410.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0    479.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    507.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    370.0      -1    3.0
#    user_id item_id  score
# 0    585.0      -1    3.0
#    user_id item_id  score
# 0    561.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    101.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    510.0      -1    3.0
#    user_id item_id  score
# 0    117.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    257.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0      2.0      -1    3.0
#    user_id item_id  score
# 0    520.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0     83.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    503.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     80.0      -1    3.0
#    user_id item_id  score
# 0    467.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    346.0      -1    3.0
#    user_id item_id  score
# 0    201.0      -1    3.0
#    user_id item_id  score
# 0    204.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    418.0      -1    3.0
#    user_id item_id  score
# 0    221.0      -1    3.0
#    user_id item_id  score
# 0    562.0      -1    3.0
#    user_id item_id  score
# 0    398.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    230.0      -1    3.0
#    user_id item_id  score
# 0     42.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    212.0      -1    3.0
#    user_id item_id  score
# 0    536.0      -1    3.0
#    user_id item_id  score
# 0    368.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    594.0      -1    3.0
#    user_id item_id  score
# 0    228.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    412.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    467.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0     45.0      -1    3.0
#    user_id item_id  score
# 0    367.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    144.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0    219.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    168.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    365.0      -1    3.0
#    user_id item_id  score
# 0      7.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    104.0      -1    3.0
#    user_id item_id  score
# 0     15.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    524.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    600.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0     96.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0     95.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    367.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    518.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    548.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    552.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0     74.0      -1    3.0
#    user_id item_id  score
# 0    592.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0     47.0      -1    3.0
#    user_id item_id  score
# 0    419.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    607.0      -1    3.0
#    user_id item_id  score
# 0    500.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    462.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    510.0      -1    3.0
#    user_id item_id  score
# 0    200.0      -1    3.0
#    user_id item_id  score
# 0     20.0      -1    3.0
#    user_id item_id  score
# 0    265.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    585.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0     41.0      -1    3.0
#    user_id item_id  score
# 0    512.0      -1    3.0
#    user_id item_id  score
# 0    592.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    373.0      -1    3.0
#    user_id item_id  score
# 0    532.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0     57.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    420.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    266.0      -1    3.0
#    user_id item_id  score
# 0    151.0      -1    3.0
#    user_id item_id  score
# 0    283.0      -1    3.0
#    user_id item_id  score
# 0    113.0      -1    3.0
#    user_id item_id  score
# 0     51.0      -1    3.0
#    user_id item_id  score
# 0    434.0      -1    3.0
#    user_id item_id  score
# 0    412.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    171.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0    600.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0     75.0      -1    3.0
#    user_id item_id  score
# 0    349.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    219.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    230.0      -1    3.0
#    user_id item_id  score
# 0    234.0      -1    3.0
#    user_id item_id  score
# 0     41.0      -1    3.0
#    user_id item_id  score
# 0    377.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    313.0      -1    3.0
#    user_id item_id  score
# 0    125.0      -1    3.0
#    user_id item_id  score
# 0    314.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    520.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    520.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    199.0      -1    3.0
#    user_id item_id  score
# 0    479.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    202.0      -1    3.0
#    user_id item_id  score
# 0    326.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    376.0      -1    3.0
#    user_id item_id  score
# 0    490.0      -1    3.0
#    user_id item_id  score
# 0    539.0      -1    3.0
#    user_id item_id  score
# 0    484.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    156.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    409.0      -1    3.0
#    user_id item_id  score
# 0     80.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    121.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0     11.0      -1    3.0
#    user_id item_id  score
# 0    110.0      -1    3.0
#    user_id item_id  score
# 0    562.0      -1    3.0
#    user_id item_id  score
# 0     36.0      -1    3.0
#    user_id item_id  score
# 0    374.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    425.0      -1    3.0
#    user_id item_id  score
# 0    524.0      -1    3.0
#    user_id item_id  score
# 0     64.0      -1    3.0
#    user_id item_id  score
# 0    520.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    268.0      -1    3.0
#    user_id item_id  score
# 0    360.0      -1    3.0
#    user_id item_id  score
# 0    200.0      -1    3.0
#    user_id item_id  score
# 0    475.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    377.0      -1    3.0
#    user_id item_id  score
# 0     29.0      -1    3.0
#    user_id item_id  score
# 0    228.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0    493.0      -1    3.0
#    user_id item_id  score
# 0     34.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    601.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    156.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    539.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    281.0      -1    3.0
#    user_id item_id  score
# 0      7.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    111.0      -1    3.0
#    user_id item_id  score
# 0    413.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    455.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    382.0      -1    3.0
#    user_id item_id  score
# 0     27.0      -1    3.0
#    user_id item_id  score
# 0    241.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0     29.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0    511.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    397.0      -1    3.0
#    user_id item_id  score
# 0    438.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0     84.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    367.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    280.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    472.0      -1    3.0
#    user_id item_id  score
# 0    268.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    587.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    211.0      -1    3.0
#    user_id item_id  score
# 0    554.0      -1    3.0
#    user_id item_id  score
# 0    136.0      -1    3.0
#    user_id item_id  score
# 0    409.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     95.0      -1    3.0
#    user_id item_id  score
# 0     70.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    536.0      -1    3.0
#    user_id item_id  score
# 0    416.0      -1    3.0
#    user_id item_id  score
# 0    357.0      -1    3.0
#    user_id item_id  score
# 0    186.0      -1    3.0
#    user_id item_id  score
# 0    537.0      -1    3.0
#    user_id item_id  score
# 0    112.0      -1    3.0
#    user_id item_id  score
# 0    570.0      -1    3.0
#    user_id item_id  score
# 0    357.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    370.0      -1    3.0
#    user_id item_id  score
# 0    129.0      -1    3.0
#    user_id item_id  score
# 0     84.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0      2.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    173.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0     66.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    369.0      -1    3.0
#    user_id item_id  score
# 0    609.0      -1    3.0
#    user_id item_id  score
# 0    100.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0     99.0      -1    3.0
#    user_id item_id  score
# 0    284.0      -1    3.0
#    user_id item_id  score
# 0    564.0      -1    3.0
#    user_id item_id  score
# 0    260.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    160.0      -1    3.0
#    user_id item_id  score
# 0    165.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    357.0      -1    3.0
#    user_id item_id  score
# 0    587.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    168.0      -1    3.0
#    user_id item_id  score
# 0    486.0      -1    3.0
#    user_id item_id  score
# 0    394.0      -1    3.0
#    user_id item_id  score
# 0     62.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    351.0      -1    3.0
#    user_id item_id  score
# 0    452.0      -1    3.0
#    user_id item_id  score
# 0    235.0      -1    3.0
#    user_id item_id  score
# 0    365.0      -1    3.0
#    user_id item_id  score
# 0    266.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    187.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    140.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    186.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    271.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0     50.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    495.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    304.0      -1    3.0
#    user_id item_id  score
# 0    500.0      -1    3.0
#    user_id item_id  score
# 0    452.0      -1    3.0
#    user_id item_id  score
# 0    215.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    393.0      -1    3.0
#    user_id item_id  score
# 0    580.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0    160.0      -1    3.0
#    user_id item_id  score
# 0    334.0      -1    3.0
#    user_id item_id  score
# 0    136.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    139.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    607.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    403.0      -1    3.0
#    user_id item_id  score
# 0    428.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    312.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    125.0      -1    3.0
#    user_id item_id  score
# 0     73.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0     90.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0     40.0      -1    3.0
#    user_id item_id  score
# 0    552.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0     15.0      -1    3.0
#    user_id item_id  score
# 0    368.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    234.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0     41.0      -1    3.0
#    user_id item_id  score
# 0    409.0      -1    3.0
#    user_id item_id  score
# 0    214.0      -1    3.0
#    user_id item_id  score
# 0    230.0      -1    3.0
#    user_id item_id  score
# 0    168.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    229.0      -1    3.0
#    user_id item_id  score
# 0    432.0      -1    3.0
#    user_id item_id  score
# 0    254.0      -1    3.0
#    user_id item_id  score
# 0     21.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    348.0      -1    3.0
#    user_id item_id  score
# 0    354.0      -1    3.0
#    user_id item_id  score
# 0    532.0      -1    3.0
#    user_id item_id  score
# 0    480.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    292.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    438.0      -1    3.0
#    user_id item_id  score
# 0     21.0      -1    3.0
#    user_id item_id  score
# 0    533.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    142.0      -1    3.0
#    user_id item_id  score
# 0    372.0      -1    3.0
#    user_id item_id  score
# 0    354.0      -1    3.0
#    user_id item_id  score
# 0    413.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    346.0      -1    3.0
#    user_id item_id  score
# 0      1.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    200.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     62.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    385.0      -1    3.0
#    user_id item_id  score
# 0    217.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    140.0      -1    3.0
#    user_id item_id  score
# 0    341.0      -1    3.0
#    user_id item_id  score
# 0    438.0      -1    3.0
#    user_id item_id  score
# 0    156.0      -1    3.0
#    user_id item_id  score
# 0    553.0      -1    3.0
#    user_id item_id  score
# 0     47.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    293.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    522.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    469.0      -1    3.0
#    user_id item_id  score
# 0    129.0      -1    3.0
#    user_id item_id  score
# 0    385.0      -1    3.0
#    user_id item_id  score
# 0     41.0      -1    3.0
#    user_id item_id  score
# 0    524.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    425.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    527.0      -1    3.0
#    user_id item_id  score
# 0    517.0      -1    3.0
#    user_id item_id  score
# 0    363.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     27.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    341.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    256.0      -1    3.0
#    user_id item_id  score
# 0    260.0      -1    3.0
#    user_id item_id  score
# 0    220.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    391.0      -1    3.0
#    user_id item_id  score
# 0    468.0      -1    3.0
#    user_id item_id  score
# 0    100.0      -1    3.0
#    user_id item_id  score
# 0    597.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    363.0      -1    3.0
#    user_id item_id  score
# 0    576.0      -1    3.0
#    user_id item_id  score
# 0     66.0      -1    3.0
#    user_id item_id  score
# 0     76.0      -1    3.0
#    user_id item_id  score
# 0    158.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     79.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    114.0      -1    3.0
#    user_id item_id  score
# 0    365.0      -1    3.0
#    user_id item_id  score
# 0    313.0      -1    3.0
#    user_id item_id  score
# 0    140.0      -1    3.0
#    user_id item_id  score
# 0    115.0      -1    3.0
#    user_id item_id  score
# 0    276.0      -1    3.0
#    user_id item_id  score
# 0    217.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0     83.0      -1    3.0
#    user_id item_id  score
# 0    482.0      -1    3.0
#    user_id item_id  score
# 0    106.0      -1    3.0
#    user_id item_id  score
# 0    351.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    109.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    425.0      -1    3.0
#    user_id item_id  score
# 0     23.0      -1    3.0
#    user_id item_id  score
# 0    367.0      -1    3.0
#    user_id item_id  score
# 0     21.0      -1    3.0
#    user_id item_id  score
# 0    210.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0    331.0      -1    3.0
#    user_id item_id  score
# 0    506.0      -1    3.0
#    user_id item_id  score
# 0    436.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    145.0      -1    3.0
#    user_id item_id  score
# 0    497.0      -1    3.0
#    user_id item_id  score
# 0    586.0      -1    3.0
#    user_id item_id  score
# 0    552.0      -1    3.0
#    user_id item_id  score
# 0    445.0      -1    3.0
#    user_id item_id  score
# 0    497.0      -1    3.0
#    user_id item_id  score
# 0    357.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0     34.0      -1    3.0
#    user_id item_id  score
# 0    225.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    177.0      -1    3.0
#    user_id item_id  score
# 0     14.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    328.0      -1    3.0
# ...
#    user_id item_id  score
# 0    331.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    201.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0     74.0      -1    3.0
#    user_id item_id  score
# 0    287.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    330.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0     76.0      -1    3.0
#    user_id item_id  score
# 0     64.0      -1    3.0
#    user_id item_id  score
# 0    445.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    222.0      -1    3.0
#    user_id item_id  score
# 0    600.0      -1    3.0
#    user_id item_id  score
# 0    485.0      -1    3.0
#    user_id item_id  score
# 0    254.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0     59.0      -1    3.0
#    user_id item_id  score
# 0    583.0      -1    3.0
#    user_id item_id  score
# 0    334.0      -1    3.0
#    user_id item_id  score
# 0     73.0      -1    3.0
#    user_id item_id  score
# 0      1.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    438.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    560.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0     52.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    495.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    333.0      -1    3.0
#    user_id item_id  score
# 0    368.0      -1    3.0
#    user_id item_id  score
# 0    517.0      -1    3.0
#    user_id item_id  score
# 0    513.0      -1    3.0
#    user_id item_id  score
# 0    156.0      -1    3.0
#    user_id item_id  score
# 0    432.0      -1    3.0
#    user_id item_id  score
# 0    198.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    182.0      -1    3.0
#    user_id item_id  score
# 0    427.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0    174.0      -1    3.0
#    user_id item_id  score
# 0    151.0      -1    3.0
#    user_id item_id  score
# 0    562.0      -1    3.0
#    user_id item_id  score
# 0      3.0      -1    3.0
#    user_id item_id  score
# 0    282.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0     21.0      -1    3.0
#    user_id item_id  score
# 0    235.0      -1    3.0
#    user_id item_id  score
# 0    480.0      -1    3.0
#    user_id item_id  score
# 0    220.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    426.0      -1    3.0
#    user_id item_id  score
# 0     62.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    496.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    533.0      -1    3.0
#    user_id item_id  score
# 0    306.0      -1    3.0
#    user_id item_id  score
# 0    446.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    156.0      -1    3.0
#    user_id item_id  score
# 0    368.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    117.0      -1    3.0
#    user_id item_id  score
# 0    368.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0     35.0      -1    3.0
#    user_id item_id  score
# 0    421.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0      4.0      -1    3.0
#    user_id item_id  score
# 0    339.0      -1    3.0
#    user_id item_id  score
# 0    274.0      -1    3.0
#    user_id item_id  score
# 0    312.0      -1    3.0
#    user_id item_id  score
# 0    452.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0     36.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    489.0      -1    3.0
#    user_id item_id  score
# 0    550.0      -1    3.0
#    user_id item_id  score
# 0    406.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    596.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    285.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    132.0      -1    3.0
#    user_id item_id  score
# 0    594.0      -1    3.0
#    user_id item_id  score
# 0    424.0      -1    3.0
#    user_id item_id  score
# 0    125.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0    103.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    199.0      -1    3.0
#    user_id item_id  score
# 0    484.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    332.0      -1    3.0
#    user_id item_id  score
# 0    344.0      -1    3.0
#    user_id item_id  score
# 0    537.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    480.0      -1    3.0
#    user_id item_id  score
# 0     45.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0    190.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0    357.0      -1    3.0
#    user_id item_id  score
# 0    462.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0    111.0      -1    3.0
#    user_id item_id  score
# 0    240.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    474.0      -1    3.0
#    user_id item_id  score
# 0     88.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     52.0      -1    3.0
#    user_id item_id  score
# 0    122.0      -1    3.0
#    user_id item_id  score
# 0    230.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     68.0      -1    3.0
#    user_id item_id  score
# 0    376.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    469.0      -1    3.0
#    user_id item_id  score
# 0    514.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    140.0      -1    3.0
#    user_id item_id  score
# 0    111.0      -1    3.0
#    user_id item_id  score
# 0    111.0      -1    3.0
#    user_id item_id  score
# 0     45.0      -1    3.0
#    user_id item_id  score
# 0    162.0      -1    3.0
#    user_id item_id  score
# 0    465.0      -1    3.0
#    user_id item_id  score
# 0    101.0      -1    3.0
#    user_id item_id  score
# 0    488.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    318.0      -1    3.0
#    user_id item_id  score
# 0    477.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    496.0      -1    3.0
#    user_id item_id  score
# 0    144.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    249.0      -1    3.0
#    user_id item_id  score
# 0    483.0      -1    3.0
#    user_id item_id  score
# 0    386.0      -1    3.0
#    user_id item_id  score
# 0    309.0      -1    3.0
#    user_id item_id  score
# 0    354.0      -1    3.0
#    user_id item_id  score
# 0    490.0      -1    3.0
#    user_id item_id  score
# 0    221.0      -1    3.0
#    user_id item_id  score
# 0    305.0      -1    3.0
#    user_id item_id  score
# 0    510.0      -1    3.0
#    user_id item_id  score
# 0    415.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    125.0      -1    3.0
#    user_id item_id  score
# 0    162.0      -1    3.0
#    user_id item_id  score
# 0    275.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    279.0      -1    3.0
#    user_id item_id  score
# 0    298.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0    287.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0     28.0      -1    3.0
#    user_id item_id  score
# 0    166.0      -1    3.0
#    user_id item_id  score
# 0    304.0      -1    3.0
#    user_id item_id  score
# 0    334.0      -1    3.0
#    user_id item_id  score
# 0    151.0      -1    3.0
#    user_id item_id  score
# 0    307.0      -1    3.0
#    user_id item_id  score
# 0    125.0      -1    3.0
#    user_id item_id  score
# 0      6.0      -1    3.0
#    user_id item_id  score
# 0    563.0      -1    3.0
#    user_id item_id  score
# 0    211.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    348.0      -1    3.0
#    user_id item_id  score
# 0     74.0      -1    3.0
#    user_id item_id  score
# 0    608.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    598.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0     39.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    212.0      -1    3.0
#    user_id item_id  score
# 0    563.0      -1    3.0
#    user_id item_id  score
# 0    290.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0     16.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    335.0      -1    3.0
#    user_id item_id  score
# 0    599.0      -1    3.0
#    user_id item_id  score
# 0    555.0      -1    3.0
#    user_id item_id  score
# 0    562.0      -1    3.0
#    user_id item_id  score
# 0     99.0      -1    3.0
#    user_id item_id  score
# 0    492.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0     57.0      -1    3.0
#    user_id item_id  score
# 0    216.0      -1    3.0
#    user_id item_id  score
# 0    263.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0    387.0      -1    3.0
#    user_id item_id  score
# 0    580.0      -1    3.0
#    user_id item_id  score
# 0     66.0      -1    3.0
#    user_id item_id  score
# 0    104.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    136.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    226.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0    610.0      -1    3.0
#    user_id item_id  score
# 0    105.0      -1    3.0
#    user_id item_id  score
# 0    367.0      -1    3.0
#    user_id item_id  score
# 0    428.0      -1    3.0
#    user_id item_id  score
# 0      7.0      -1    3.0
#    user_id item_id  score
# 0     57.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    356.0      -1    3.0
#    user_id item_id  score
# 0    603.0      -1    3.0
#    user_id item_id  score
# 0    104.0      -1    3.0
#    user_id item_id  score
# 0     66.0      -1    3.0
#    user_id item_id  score
# 0    601.0      -1    3.0
#    user_id item_id  score
# 0    381.0      -1    3.0
#    user_id item_id  score
# 0    256.0      -1    3.0
#    user_id item_id  score
# 0     18.0      -1    3.0
#    user_id item_id  score
# 0    288.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0     91.0      -1    3.0
#    user_id item_id  score
# 0    453.0      -1    3.0
#    user_id item_id  score
# 0    533.0      -1    3.0
#    user_id item_id  score
# 0    534.0      -1    3.0
#    user_id item_id  score
# 0    525.0      -1    3.0
#    user_id item_id  score
# 0    377.0      -1    3.0
#    user_id item_id  score
# 0     74.0      -1    3.0
#    user_id item_id  score
# 0    112.0      -1    3.0
#    user_id item_id  score
# 0    414.0      -1    3.0
#    user_id item_id  score
# 0    380.0      -1    3.0
#    user_id item_id  score
# 0    129.0      -1    3.0
#    user_id item_id  score
# 0    187.0      -1    3.0
#    user_id item_id  score
# 0    140.0      -1    3.0
#    user_id item_id  score
# 0    567.0      -1    3.0
#    user_id item_id  score
# 0    509.0      -1    3.0
#    user_id item_id  score
# 0    573.0      -1    3.0
#    user_id item_id  score
# 0    247.0      -1    3.0
#    user_id item_id  score
# 0    232.0      -1    3.0
#    user_id item_id  score
# 0     19.0      -1    3.0
#    user_id item_id  score
# 0    294.0      -1    3.0
#    user_id item_id  score
# 0    590.0      -1    3.0
#    user_id item_id  score
# 0    429.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0    325.0      -1    3.0
#    user_id item_id  score
# 0     89.0      -1    3.0
#    user_id item_id  score
# 0     57.0      -1    3.0
#    user_id item_id  score
# 0    448.0      -1    3.0
#    user_id item_id  score
# 0     64.0      -1    3.0
#    user_id item_id  score
# 0    606.0      -1    3.0
#    user_id item_id  score
# 0    202.0      -1    3.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7488/1237881439.py in <module>
#      45 recommender = Recommender()
#      46
# ---> 47 results = [['BaseRecommender'] + list(evaluate_train_test_split_explicit(
#      48     recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df))]
#      49
#
# ~\AppData\Local\Temp/ipykernel_7488/1237881439.py in evaluate_train_test_split_explicit(recommender, interactions_df, items_df, seed)
#      41     # Return evaluation metrics
#      42
# ---> 43     return rmse(r_pred, r_real), mre(r_pred, r_real), tre(r_pred, r_real)
#      44
#      45 recommender = Recommender()
#
# NameError: name 'rmse' is not defined

# %% [markdown]
# ### Implicit feedback

# %%
def evaluate_train_test_split_implicit(recommender, interactions_df, items_df, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    if type(interactions_df) == 'dict':
        # If interactions_df is a dict with already split data, use the split
        interactions_df_train = interactions_df['train']
        interactions_df_test = interactions_df['test']
    else:    
        # Otherwise split the dataset into train and test

        shuffle = np.arange(len(interactions_df))
        rng.shuffle(shuffle)
        shuffle = list(shuffle)

        train_test_split = 0.8
        split_index = int(len(interactions_df) * train_test_split)

        interactions_df_train = interactions_df.iloc[shuffle[:split_index]]
        interactions_df_test = interactions_df.iloc[shuffle[split_index:]]
    
    hr_1 = []
    hr_3 = []
    hr_5 = []
    hr_10 = []
    ndcg_1 = []
    ndcg_3 = []
    ndcg_5 = []
    ndcg_10 = []
    
    # Train the recommender
    
    recommender.fit(interactions_df_train, None, items_df)
    
    # Make recommendations for each user in the test set and calculate the metric 
    # against all items of that user in the test set
    
    test_user_interactions = interactions_df_test.groupby(by='user_id')
    
    for user_id, user_interactions in test_user_interactions:
        
        # recommend user with their items
        recommendations = recommender.recommend(pd.DataFrame([user_id], columns=['user_id']), 
                                                items_df, n_recommendations=10)
        
        hr_1.append(hr(recommendations, user_interactions, n=1))
        hr_3.append(hr(recommendations, user_interactions, n=3))
        hr_5.append(hr(recommendations, user_interactions, n=5))
        hr_10.append(hr(recommendations, user_interactions, n=10))
        ndcg_1.append(ndcg(recommendations, user_interactions, n=1))
        ndcg_3.append(ndcg(recommendations, user_interactions, n=3))
        ndcg_5.append(ndcg(recommendations, user_interactions, n=5))
        ndcg_10.append(ndcg(recommendations, user_interactions, n=10))
                
    hr_1 = np.mean(hr_1)
    hr_3 = np.mean(hr_3)
    hr_5 = np.mean(hr_5)
    hr_10 = np.mean(hr_10)
    ndcg_1 = np.mean(ndcg_1)
    ndcg_3 = np.mean(ndcg_3)
    ndcg_5 = np.mean(ndcg_5)
    ndcg_10 = np.mean(ndcg_10)
    
    return hr_1, hr_3, hr_5, hr_10, ndcg_1, ndcg_3, ndcg_5, ndcg_10

recommender = Recommender()

results = [['BaseRecommender'] + list(evaluate_train_test_split_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Leave-one-out, leave-k-out, cross-validation

# %% [markdown]
# ### Explicit feedback

# %%
def evaluate_leave_one_out_explicit(recommender, interactions_df, items_df, max_evals=300, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    # Prepare splits of the datasets
    kf = KFold(n_splits=len(interactions_df), random_state=rng, shuffle=True)
    
    # For each split of the dataset train the recommender, generate recommendations and evaluate
    
    r_pred = []
    r_real = []
    n_eval = 1
    for train_index, test_index in kf.split(interactions_df.index):
        interactions_df_train = interactions_df.loc[interactions_df.index[train_index]]
        interactions_df_test = interactions_df.loc[interactions_df.index[test_index]]

        recommender.fit(interactions_df_train, None, items_df)
        recommendations = recommender.recommend(interactions_df_test.loc[:, ['user_id']], 
                                                items_df.loc[items_df['item_id'] == interactions_df_test.iloc[0]['item_id']])
        
        r_pred.append(recommendations.iloc[0]['score'])
        r_real.append(interactions_df_test.iloc[0]['rating'])
        
        if n_eval == max_evals:
            break
        n_eval += 1
        
    r_pred = np.array(r_pred)
    r_real = np.array(r_real)
        
    # Return evaluation metrics
    
    return rmse(r_pred, r_real), mre(r_pred, r_real), tre(r_pred, r_real)

recommender = Recommender()

results = [['BaseRecommender'] + list(evaluate_leave_one_out_explicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>RMSE</th>
#       <th>MRE</th>
#       <th>TRE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>1.161536</td>
#       <td>0.382929</td>
#       <td>0.267866</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Implicit feedback

# %%
def evaluate_leave_one_out_implicit(recommender, interactions_df, items_df, max_evals=300, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    # Prepare splits of the datasets
    kf = KFold(n_splits=len(interactions_df), random_state=rng, shuffle=True)
    
    hr_1 = []
    hr_3 = []
    hr_5 = []
    hr_10 = []
    ndcg_1 = []
    ndcg_3 = []
    ndcg_5 = []
    ndcg_10 = []
    
    # For each split of the dataset train the recommender, generate recommendations and evaluate
    
    n_eval = 1
    for train_index, test_index in kf.split(interactions_df.index):
        interactions_df_train = interactions_df.loc[interactions_df.index[train_index]]
        interactions_df_test = interactions_df.loc[interactions_df.index[test_index]]
                
        recommender.fit(interactions_df_train, None, items_df)
        recommendations = recommender.recommend(interactions_df_test.loc[:, ['user_id']], items_df, n_recommendations=10)
        
        hr_1.append(hr(recommendations, interactions_df_test, n=1))
        hr_3.append(hr(recommendations, interactions_df_test, n=3))
        hr_5.append(hr(recommendations, interactions_df_test, n=5))
        hr_10.append(hr(recommendations, interactions_df_test, n=10))
        ndcg_1.append(ndcg(recommendations, interactions_df_test, n=1))
        ndcg_3.append(ndcg(recommendations, interactions_df_test, n=3))
        ndcg_5.append(ndcg(recommendations, interactions_df_test, n=5))
        ndcg_10.append(ndcg(recommendations, interactions_df_test, n=10))
        
        if n_eval == max_evals:
            break
        n_eval += 1
        
    hr_1 = np.mean(hr_1)
    hr_3 = np.mean(hr_3)
    hr_5 = np.mean(hr_5)
    hr_10 = np.mean(hr_10)
    ndcg_1 = np.mean(ndcg_1)
    ndcg_3 = np.mean(ndcg_3)
    ndcg_5 = np.mean(ndcg_5)
    ndcg_10 = np.mean(ndcg_10)
    
    return hr_1, hr_3, hr_5, hr_10, ndcg_1, ndcg_3, ndcg_5, ndcg_10

recommender = Recommender()

results = [['BaseRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Examples of evaluation

# %% [markdown]
# ## Explicit feedback

# %% [markdown]
# ### Train-test split test

# %%
from recommenders.basic_recommenders import MostPopularRecommender
from recommenders.basic_recommenders import HighestRatedRecommender
from recommenders.basic_content_based_recommenders import LinearRegressionRecommender
from recommenders.basic_content_based_recommenders import SVRRecommender
from recommenders.nearest_neighbors_recommender import ItemBasedCosineNearestNeighborsRecommender

highest_rated_recommender = HighestRatedRecommender()
lr_recommender = LinearRegressionRecommender()
svr_recommender = SVRRecommender()

recommenders = [highest_rated_recommender, lr_recommender, svr_recommender]

all_results = []

t0 = time.time()

for recommender in recommenders:
    results = [[type(recommender).__name__] + list(evaluate_train_test_split_explicit(
        recommender, ml_ratings_df, ml_movies_df))]

    results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])
    all_results.append(results)

    display(results)
    
all_results = pd.concat(all_results).reset_index(drop=True)
display(all_results)

print('Total evaluation time: {}'.format(time.time() - t0))
# Out:
#                Recommender      RMSE       MRE       TRE
# 0  HighestRatedRecommender  1.272994  0.481631  0.277884
#                    Recommender      RMSE       MRE      TRE
# 0  LinearRegressionRecommender  1.003323  0.345736  0.22714
#       Recommender      RMSE       MRE       TRE
# 0  SVRRecommender  0.974559  0.332425  0.218618
#                    Recommender      RMSE       MRE       TRE
# 0      HighestRatedRecommender  1.272994  0.481631  0.277884
# 1  LinearRegressionRecommender  1.003323  0.345736  0.227140
# 2               SVRRecommender  0.974559  0.332425  0.218618
# Total evaluation time: 42.968801498413086

# %% [markdown]
# ### Leave-one-out test

# %%
from recommenders.basic_recommenders import MostPopularRecommender
from recommenders.basic_recommenders import HighestRatedRecommender
from recommenders.basic_content_based_recommenders import LinearRegressionRecommender
from recommenders.basic_content_based_recommenders import SVRRecommender
from recommenders.nearest_neighbors_recommender import ItemBasedCosineNearestNeighborsRecommender

highest_rated_recommender = HighestRatedRecommender()
lr_recommender = LinearRegressionRecommender()
svr_recommender = SVRRecommender()

recommenders = [highest_rated_recommender, lr_recommender, svr_recommender]

all_results = []

t0 = time.time()

for recommender in recommenders:
    results = [[type(recommender).__name__] + list(evaluate_leave_one_out_explicit(
        recommender, ml_ratings_df, ml_movies_df))]

    results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])
    all_results.append(results)

    display(results)
    
all_results = pd.concat(all_results).reset_index(drop=True)
display(all_results)

print('Total evaluation time: {}'.format(time.time() - t0))
# Out:
#                Recommender      RMSE       MRE       TRE
# 0  HighestRatedRecommender  1.380808  0.579605  0.313605
#                    Recommender      RMSE       MRE       TRE
# 0  LinearRegressionRecommender  1.039763  0.401878  0.240408
#       Recommender      RMSE       MRE       TRE
# 0  SVRRecommender  1.012044  0.386537  0.230015
#                    Recommender      RMSE       MRE       TRE
# 0      HighestRatedRecommender  1.380808  0.579605  0.313605
# 1  LinearRegressionRecommender  1.039763  0.401878  0.240408
# 2               SVRRecommender  1.012044  0.386537  0.230015
# Total evaluation time: 664.6288876533508

# %% [markdown]
# ## Implicit feedback

# %% [markdown]
# ### Train-test split test

# %%
from recommenders.basic_recommenders import MostPopularRecommender
from recommenders.basic_recommenders import HighestRatedRecommender
from recommenders.basic_content_based_recommenders import LinearRegressionRecommender
from recommenders.basic_content_based_recommenders import SVRRecommender
from recommenders.nearest_neighbors_recommender import ItemBasedCosineNearestNeighborsRecommender

most_popular_recommender = MostPopularRecommender()
highest_rated_recommender = HighestRatedRecommender()
lr_recommender = LinearRegressionRecommender()
svr_recommender = SVRRecommender()
ibcnn_recommender = ItemBasedCosineNearestNeighborsRecommender(n_neighbors=30)

recommenders = [most_popular_recommender, highest_rated_recommender, lr_recommender, svr_recommender, ibcnn_recommender]

all_results = []

t0 = time.time()

for recommender in recommenders:
    results = [[type(recommender).__name__] + list(evaluate_train_test_split_implicit(
        recommender, ml_ratings_df, ml_movies_df))]

    results = pd.DataFrame(results, 
                           columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])
    all_results.append(results)

    display(results)
    
all_results = pd.concat(all_results).reset_index(drop=True)
display(all_results)

print('Total evaluation time: {}'.format(time.time() - t0))
# Out:
#               Recommender      HR@1      HR@3      HR@5     HR@10    NDCG@1  \
# 0  MostPopularRecommender  0.076063  0.284116  0.440716  0.680089  0.076063
#
#      NDCG@3    NDCG@5   NDCG@10
# 0  0.192392  0.256306  0.332798
#                Recommender      HR@1      HR@3      HR@5     HR@10    NDCG@1  \
# 0  HighestRatedRecommender  0.114094  0.239374  0.331096  0.568233  0.114094
#
#      NDCG@3    NDCG@5   NDCG@10
# 0  0.186693  0.224823  0.302199
#                    Recommender      HR@1      HR@3      HR@5     HR@10  \
# 0  LinearRegressionRecommender  0.006711  0.006711  0.006711  0.006711
#
#      NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.006711  0.006711  0.006711  0.006711
#       Recommender      HR@1      HR@3      HR@5     HR@10    NDCG@1    NDCG@3  \
# 0  SVRRecommender  0.006711  0.006711  0.006711  0.006711  0.006711  0.006711
#
#      NDCG@5   NDCG@10
# 0  0.006711  0.006711
#                                   Recommender     HR@1      HR@3      HR@5  \
# 0  ItemBasedCosineNearestNeighborsRecommender  0.14094  0.404922  0.610738
#
#       HR@10   NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.955257  0.14094  0.291677  0.376199  0.488492
#                                   Recommender      HR@1      HR@3      HR@5  \
# 0                      MostPopularRecommender  0.076063  0.284116  0.440716
# 1                     HighestRatedRecommender  0.114094  0.239374  0.331096
# 2                 LinearRegressionRecommender  0.006711  0.006711  0.006711
# 3                              SVRRecommender  0.006711  0.006711  0.006711
# 4  ItemBasedCosineNearestNeighborsRecommender  0.140940  0.404922  0.610738
#
#       HR@10    NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.680089  0.076063  0.192392  0.256306  0.332798
# 1  0.568233  0.114094  0.186693  0.224823  0.302199
# 2  0.006711  0.006711  0.006711  0.006711  0.006711
# 3  0.006711  0.006711  0.006711  0.006711  0.006711
# 4  0.955257  0.140940  0.291677  0.376199  0.488492
# Total evaluation time: 197.76915740966797

# %% [markdown]
# ### Leave-one-out test

# %%
from recommenders.basic_recommenders import MostPopularRecommender
from recommenders.basic_recommenders import HighestRatedRecommender
from recommenders.basic_content_based_recommenders import LinearRegressionRecommender
from recommenders.basic_content_based_recommenders import SVRRecommender
from recommenders.nearest_neighbors_recommender import ItemBasedCosineNearestNeighborsRecommender

most_popular_recommender = MostPopularRecommender()
highest_rated_recommender = HighestRatedRecommender()
lr_recommender = LinearRegressionRecommender()
svr_recommender = SVRRecommender()
ibcnn_recommender = ItemBasedCosineNearestNeighborsRecommender(n_neighbors=30)

recommenders = [most_popular_recommender, highest_rated_recommender, lr_recommender, svr_recommender, ibcnn_recommender]

all_results = []

t0 = time.time()

for recommender in recommenders:
    results = [[type(recommender).__name__] + list(evaluate_leave_one_out_implicit(
        recommender, ml_ratings_df, ml_movies_df))]

    results = pd.DataFrame(results, 
                           columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])
    all_results.append(results)

    display(results)
    
all_results = pd.concat(all_results).reset_index(drop=True)
display(all_results)

print('Total evaluation time: {}'.format(time.time() - t0))
# Out:
#               Recommender      HR@1  HR@3      HR@5     HR@10    NDCG@1  \
# 0  MostPopularRecommender  0.026667  0.05  0.083333  0.163333  0.026667
#
#      NDCG@3    NDCG@5   NDCG@10
# 0  0.040079  0.053997  0.079749
#                Recommender      HR@1  HR@3      HR@5     HR@10    NDCG@1  \
# 0  HighestRatedRecommender  0.013333  0.04  0.073333  0.113333  0.013333
#
#     NDCG@3    NDCG@5   NDCG@10
# 0  0.02754  0.041603  0.054395
#                    Recommender      HR@1      HR@3      HR@5     HR@10  \
# 0  LinearRegressionRecommender  0.003333  0.003333  0.003333  0.003333
#
#      NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.003333  0.003333  0.003333  0.003333
#       Recommender      HR@1      HR@3      HR@5     HR@10    NDCG@1    NDCG@3  \
# 0  SVRRecommender  0.003333  0.003333  0.003333  0.003333  0.003333  0.003333
#
#      NDCG@5   NDCG@10
# 0  0.003333  0.003333
#                                   Recommender      HR@1  HR@3      HR@5  \
# 0  ItemBasedCosineNearestNeighborsRecommender  0.076667  0.17  0.233333
#
#       HR@10    NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.333333  0.076667  0.128134  0.154096  0.186049
#                                   Recommender      HR@1      HR@3      HR@5  \
# 0                      MostPopularRecommender  0.026667  0.050000  0.083333
# 1                     HighestRatedRecommender  0.013333  0.040000  0.073333
# 2                 LinearRegressionRecommender  0.003333  0.003333  0.003333
# 3                              SVRRecommender  0.003333  0.003333  0.003333
# 4  ItemBasedCosineNearestNeighborsRecommender  0.076667  0.170000  0.233333
#
#       HR@10    NDCG@1    NDCG@3    NDCG@5   NDCG@10
# 0  0.163333  0.026667  0.040079  0.053997  0.079749
# 1  0.113333  0.013333  0.027540  0.041603  0.054395
# 2  0.003333  0.003333  0.003333  0.003333  0.003333
# 3  0.003333  0.003333  0.003333  0.003333  0.003333
# 4  0.333333  0.076667  0.128134  0.154096  0.186049
# Total evaluation time: 995.216691493988
